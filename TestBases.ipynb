# %%
import src
A = src.getRGCStimBasis(bin_size_ms=0.5, orthogonalize=False)

# %%
import matplotlib.pyplot as plt

plt.plot(A.T,A.B)
plt.show()

# %%
import numpy as np
Stim = np.random.randn((2000))

(X, tts,  window_rounded, window_bins) = A.convolve_continuous_event(Stim,(300,600))
plt.plot(tts,X)
plt.show()
# Out:
# Doing what I think 378, 978
